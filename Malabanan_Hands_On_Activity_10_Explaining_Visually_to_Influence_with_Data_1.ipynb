# %% [markdown]
# <a href="https://colab.research.google.com/github/qnamalabanan-netizen/CPE-031---Visualization-and-Data-Analysis/blob/main/Malabanan_Hands_On_Activity_10_Explaining_Visually_to_Influence_with_Data_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Hands-On Activity 10 | Explaining Visually to Influence with Data**
#
#
#
#
#
# ---

# %% [markdown]
# Name : Nadine A. Malabanan <br>
# Course Code and Title : CPE 031- Visualization and Data Analysis <br>
# Date Submitted :10/30/2025<br>
# Instructor : Engr. Maria Rizzette Sayo
#
#
# ---

# %% [markdown]
# **1. Objectives:**
#
# This activity aims to help students demonstrate how to influence and communicate effectively with data by identifying audience needs, crafting a clear message, and telling a story visually through charts.

# %% [markdown]
# **2. Intended Learning Outcomes (ILOs):**
#
# By the end of this activity, students should be able to:
#
# 1. Analyze the audience to understand their level of data knowledge and needs.
#
# 2. Evaluate how well a message and visualization communicate insights.
#
# 3. Create a clear and meaningful data story using Python visualization tools.

# %% [markdown]
# **3. Discussions:**
#
# Data storytelling goes beyond showing charts it’s about influencing decisions and sparking understanding.
#
# Know Your Audience: Decision-makers may prefer clear summaries, while analysts like detailed data.
#
# Know Your Message: Focus on the why it matters part of the story.
#
# Tell a Story: Use preattentive attributes color, size, and position to guide attention.
#
# Structure Your Story: Like Aristotle’s rhetorical triangle, combine logic (logos), emotion (pathos), and credibility (ethos).

# %% [markdown]
# **4. Procedures:**

# %% [markdown]
# Step 1. Import Libraries and Create Sample Data

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Sample sales dataset
data = {
    "Month": ["Jan", "Feb", "Mar", "Apr", "May", "Jun"],
    "Sales": [200, 250, 180, 300, 280, 350],
    "Marketing_Spend": [50, 60, 45, 70, 65, 80]
}
df = pd.DataFrame(data)
df
# Out:
#   Month  Sales  Marketing_Spend
# 0   Jan    200               50
# 1   Feb    250               60
# 2   Mar    180               45
# 3   Apr    300               70
# 4   May    280               65
# 5   Jun    350               80

# %% [markdown]
# Step 2. Know Your Audience — Compare Chart Styles

# %%
# Executive audience: prefer clarity (simple bar)
plt.figure(figsize=(7,4))
sns.barplot(x="Month", y="Sales", data=df, color="steelblue")
plt.title("Executive View: Monthly Sales Overview", fontsize=13)
plt.show()

# Analyst audience: prefer detailed trends (line chart)
plt.figure(figsize=(7,4))
sns.lineplot(x="Month", y="Sales", data=df, marker="o", label="Sales")
sns.lineplot(x="Month", y="Marketing_Spend", data=df, marker="o", label="Marketing Spend")
plt.title("Analyst View: Sales vs Marketing Trend", fontsize=13)
plt.legend()
plt.show()

# %% [markdown]
# **Task 1:** Create one additional visualization suited for a different audience (e.g., a customer, investor, or teammate).

# %%
plt.figure(figsize=(7,4))
sns.lineplot(x="Month", y="Sales", data=df, marker="o", label="Sales")
sns.lineplot(x="Month", y="Marketing_Spend", data=df, marker="o", label="Marketing Spend")
plt.title("Team View: Sales and Marketing Spend Analysis", fontsize=13)
plt.xlabel("Month")
plt.ylabel("Amount")
plt.legend()
plt.show()

# %% [markdown]
# Step 3. Know Your Message — Highlight What Matters

# %%
# Highlight the highest sales month (preattentive color cue)
highlight = df["Sales"].idxmax()

colors = ["gray" if i != highlight else "crimson" for i in range(len(df))]
plt.figure(figsize=(7,4))
plt.bar(df["Month"], df["Sales"], color=colors)
plt.title("Highlighting the Best Month in Sales", fontsize=13)
plt.show()

# %% [markdown]
# **Task 2:** Use color or annotations to emphasize a key insight (e.g., lowest point, sudden increase).

# %%
lowest_sales_month = df["Sales"].idxmin()

colors_lowest = ["gray" if i != lowest_sales_month else "darkorange" for i in range(len(df))]
plt.figure(figsize=(7,4))
plt.bar(df["Month"], df["Sales"], color=colors_lowest)
plt.title("Highlighting the Lowest Month in Sales", fontsize=13)
plt.show()

# %% [markdown]
# Step 4. Storytelling with Charts — Beginning, Middle, End

# %%
# Beginning: Context
plt.figure(figsize=(7,4))
sns.barplot(x="Month", y="Sales", data=df, color="skyblue")
plt.title("Beginning: Sales Started Steady", fontsize=13)
plt.show()

# Middle: Change or Challenge
plt.figure(figsize=(7,4))
sns.lineplot(x="Month", y="Sales", data=df, color="orange", marker="o")
plt.title("Middle: A Drop in March Due to Low Marketing", fontsize=13)
plt.show()

# End: Resolution
plt.figure(figsize=(7,4))
sns.barplot(x="Month", y="Sales", data=df, color="limegreen")
plt.title("End: Recovery and Growth After March", fontsize=13)
plt.show()

# %% [markdown]
# **Task 3:** Write one or two lines describing your data story from beginning → middle → end.

# %% [markdown]
# **Answer:** The data story begins with steady sales at the start of the year. In the middle, there is a noticeable drop in sales in March, which appears to be related to lower marketing spend during that month. The story concludes with a recovery and growth in sales after March, suggesting that increased marketing efforts had a positive impact.

# %% [markdown]
# Step 5. Bringing It All Together — Presentation Design

# %%
# Simple combined story chart
plt.figure(figsize=(8,5))
sns.lineplot(x="Month", y="Sales", data=df, marker="o", linewidth=2, color="royalblue", label="Sales")
sns.lineplot(x="Month", y="Marketing_Spend", data=df, marker="o", linestyle="--", color="orange", label="Marketing Spend")

plt.fill_between(df["Month"], df["Sales"], alpha=0.1, color="royalblue")
plt.title("From Effort to Impact: Marketing Spend Drives Sales Growth", fontsize=13)
plt.legend()
plt.show()

# %% [markdown]
# ---
#
#
# **5. Supplementary Activity:**

# %% [markdown]
# 1. Use a small dataset available online (kaggle, google dataset, etc.).
#
# 2. Visualize it using a bar chart.
#
# 3. Highlight one important data point (e.g., the highest or lowest value) using a distinct color.
#
# 4. Add a title and annotation that tell the story behind the data.

# %% [markdown]
# *Type it here

# %%
import seaborn as sns


df_new = sns.load_dataset("tips")


display(df_new.head())
display(df_new.info())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None

# %%
# Create a bar chart using seaborn
bar_chart = sns.barplot(x="day", y="total_bill", data=df_new)
plt.title("Average Total Bill by Day of the Week")
plt.xlabel("Day of the Week")
plt.ylabel("Average Total Bill")
plt.show()

# %%
average_bill_by_day = df_new.groupby("day")["total_bill"].mean().reset_index()

highest_avg_day = average_bill_by_day.loc[average_bill_by_day["total_bill"].idxmax()]

colors = ["gray" if day != highest_avg_day["day"] else "crimson" for day in average_bill_by_day["day"]]

plt.figure(figsize=(8, 5))
plt.bar(average_bill_by_day["day"], average_bill_by_day["total_bill"], color=colors)
plt.title("Average Total Bill by Day of the Week (Highest Day Highlighted)", fontsize=14)
plt.xlabel("Day of the Week", fontsize=12)
plt.ylabel("Average Total Bill", fontsize=12)
plt.show()
# Out:
# /tmp/ipython-input-3447254022.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   average_bill_by_day = df_new.groupby("day")["total_bill"].mean().reset_index()

# %%
plt.figure(figsize=(8, 5))
bars = plt.bar(average_bill_by_day["day"], average_bill_by_day["total_bill"], color=colors)
plt.title("Sunday Funday: Highest Average Bill Day", fontsize=14)
plt.xlabel("Day of the Week", fontsize=12)
plt.ylabel("Average Total Bill", fontsize=12)

#highest bar
for bar in bars:
    yval = bar.get_height()
    if bar.get_facecolor() == plt.cm.colors.to_rgba("crimson"):
        plt.text(bar.get_x() + bar.get_width()/2, yval, f'${yval:.2f}', ha='center', va='bottom')

plt.show()

# %%
**6. Conclusion/Learnings/Analysis:**

# %% [markdown]
# In my conclusion, Doing this activity helped me understand how important it is to think about who is going to look at my charts. It's not just about making pretty pictures; it's about making sure the right people get the message they need. When I made charts for different groups like executives or teammates, I saw how changing the chart style or what I highlighted made a big difference in what story the data told.
#
# I also learned that simple things like using a different color for one bar on a chart can really make something stand out. Highlighting the best or worst month in sales with color made it super clear which months were important to look at. Adding notes or titles that explain the chart helps a lot too, especially when I want to point out something specific.
#
# Working with the tips dataset in the supplementary task was good practice. I got to use what I learned about making bar charts and highlighting data on a new set of information. Finding the busiest day Sunday! and pointing it out on the chart with a label felt like I was actually telling a small story with the data.
#
# Overall, this activity taught me that making good data visualizations is a lot like telling a story. You have to know your audience, know what you want to say, and use the tools you have like colors, titles, and annotations to make sure your story is clear and easy to understand so people can use the data to make decisions.
